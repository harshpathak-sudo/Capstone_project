# %%
spark.conf.set(
  "fs.azure.account.key.adlsnewhp1.dfs.core.windows.net",
   dbutils.secrets.get(scope="key-vault-scope", key="adls-key")
)
